# %% [markdown]
# # =============================================================================
# # PROJETO: MNIST Digit Classifier - Análise Preditiva Multiclasse
# # AUTOR: [Seu Nome]
# # DATA: [Data Atual]
# # DESCRIÇÃO: Pipeline completo de Machine Learning para classificação de
# #            dígitos manuscritos usando o dataset MNIST.
# #            Modelos: Random Forest, KNN e MLP (scikit-learn)
# # =============================================================================

# %%
# -----------------------------------------------------------------------------
# IMPORTAÇÕES DE BIBLIOTECAS CORE
# -----------------------------------------------------------------------------

# NumPy: operações matemáticas e arrays multidimensionais
import numpy as np

# Pandas: manipulação e análise de dados tabulares
import pandas as pd

# Matplotlib: criação de gráficos e visualizações
import matplotlib.pyplot as plt

# Seaborn: visualização estatística (heatmaps mais elegantes)
import seaborn as sns

# Time: medição de tempo de execução
import time

# Warnings: controle de avisos
import warnings
warnings.filterwarnings('ignore')

# -----------------------------------------------------------------------------
# IMPORTAÇÕES DE MACHINE LEARNING (Scikit-Learn)
# -----------------------------------------------------------------------------

# fetch_openml: baixar datasets do OpenML (incluindo MNIST)
from sklearn.datasets import fetch_openml

# train_test_split: dividir dados em treino/validação/teste
from sklearn.model_selection import train_test_split

# StandardScaler: normalização de dados
from sklearn.preprocessing import StandardScaler

# Modelos de Machine Learning
from sklearn.ensemble import RandomForestClassifier  # Ensemble de árvores
from sklearn.neighbors import KNeighborsClassifier   # K vizinhos mais próximos
from sklearn.neural_network import MLPClassifier     # Rede neural MLP

# Métricas de avaliação
from sklearn.metrics import (
    accuracy_score,         # Acurácia global
    precision_score,        # Precisão
    recall_score,           # Revocação/Sensibilidade
    f1_score,               # F1-Score (média harmônica)
    confusion_matrix,       # Matriz de confusão
    classification_report   # Relatório completo de métricas
)

# -----------------------------------------------------------------------------
# IMPORTAÇÕES PARA PROCESSAMENTO DE IMAGENS (Desafio C)
# -----------------------------------------------------------------------------

from PIL import Image, ImageOps  # Manipulação de imagens

# -----------------------------------------------------------------------------
# CONFIGURAÇÕES DE VISUALIZAÇÃO
# -----------------------------------------------------------------------------

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12

# Semente aleatória para reprodutibilidade
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

print("=" * 80)
print("🧠 MNIST - ANÁLISE PREDITIVA MULTICLASSE")
print("=" * 80)
print("✅ Todas as importações realizadas com sucesso!")
print(f"📌 Modelos: Random Forest, KNN, MLP (scikit-learn)")
print("=" * 80)
